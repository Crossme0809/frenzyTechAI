# %% [markdown]
# <a href="https://colab.research.google.com/github/Crossme0809/frenzyTechAI/blob/main/onprem/OnPrem_LLM_QuickStart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OnPrem.LLM 演示
#
# [OnPrem.LLM](https://github.com/amaiya/onprem) 是一个简单的 Python 库，用于使用非公开数据运行本地大型语言模型。
#
# 我们将使用默认的 7B 参数模型，但您可以通过提供 `use_larger=True` 使用默认的 13B 模型。您还可以提供不同模型的 URL。该笔记本还演示了 GPU 卸载。
#
# **OnPrem.LLM** 的完整文档可在此处获取。 [here](https://amaiya.github.io/onprem/).

# %%
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install -q --upgrade --force-reinstall llama-cpp-python --no-cache-dir
# !pip install onprem
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 75.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 106.6 MB/s eta 0:00:00
#   Building wheel for llama-cpp-python (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.2 which is incompatible.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.25.2 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.7.1 which is incompatible.
# Collecting onprem
#   Downloading onprem-0.0.12-py3-none-any.whl (17 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onprem) (2.31.0)
# Collecting langchain==0.0.240 (from onprem)
#   Downloading langchain-0.0.240-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.6 MB/s eta 0:00:00
# Collecting chromadb==0.4.7 (from onprem)
#   Downloading chromadb-0.4.7-py3-none-any.whl (415 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 415.5/415.5 kB 37.9 MB/s eta 0:00:00
# Collecting PyMuPDF==1.23.1 (from onprem)
#   Downloading PyMuPDF-1.23.1-cp310-none-manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 87.1 MB/s eta 0:00:00
# Collecting unstructured==0.10.8 (from onprem)
#   Downloading unstructured-0.10.8-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 75.2 MB/s eta 0:00:00
# Collecting extract-msg==0.45.0 (from onprem)
#   Downloading extract_msg-0.45.0-py2.py3-none-any.whl (303 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.4/303.4 kB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: tabulate==0.9.0 in /usr/local/lib/python3.10/dist-packages (from onprem) (0.9.0)
# Collecting pandoc==2.3 (from onprem)
#   Downloading pandoc-2.3.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pypandoc==1.11 (from onprem)
#   Downloading pypandoc-1.11-py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.10/dist-packages (from onprem) (4.66.1)
# Collecting sentence-transformers==2.2.2 (from onprem)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: llama-cpp-python==0.1.69 in /usr/local/lib/python3.10/dist-packages (from onprem) (0.1.69)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.7->onprem) (1.10.12)
# Collecting chroma-hnswlib==0.7.2 (from chromadb==0.4.7->onprem)
#   Downloading chroma-hnswlib-0.7.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fastapi<0.100.0,>=0.95.2 (from chromadb==0.4.7->onprem)
#   Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 233.7 kB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb==0.4.7->onprem)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.7->onprem) (1.25.2)
# Collecting posthog>=2.4.0 (from chromadb==0.4.7->onprem)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.7->onprem) (4.7.1)
# Collecting pulsar-client>=3.1.0 (from chromadb==0.4.7->onprem)
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 39.3 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb==0.4.7->onprem)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 77.0 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.2 (from chromadb==0.4.7->onprem)
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.0 MB/s eta 0:00:00
# Collecting pypika>=0.48.9 (from chromadb==0.4.7->onprem)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb==0.4.7->onprem)
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.7->onprem) (6.0.1)
# Collecting bcrypt>=4.0.1 (from chromadb==0.4.7->onprem)
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 54.6 MB/s eta 0:00:00
# Collecting imapclient<3,>=2.3.0 (from extract-msg==0.45.0->onprem)
#   Downloading IMAPClient-2.3.1-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 20.6 MB/s eta 0:00:00
# Collecting olefile==0.46 (from extract-msg==0.45.0->onprem)
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tzlocal<6,>=4.2 in /usr/local/lib/python3.10/dist-packages (from extract-msg==0.45.0->onprem) (5.0.1)
# Collecting compressed-rtf<2,>=1.0.6 (from extract-msg==0.45.0->onprem)
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ebcdic<2,>=1.1.1 (from extract-msg==0.45.0->onprem)
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<4.13,>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg==0.45.0->onprem) (4.11.2)
# Collecting RTFDE<0.2,>=0.1.0 (from extract-msg==0.45.0->onprem)
#   Downloading RTFDE-0.1.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 7.5 MB/s eta 0:00:00
# Collecting red-black-tree-mod==1.20 (from extract-msg==0.45.0->onprem)
#   Downloading red-black-tree-mod-1.20.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.240->onprem) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.240->onprem) (2.0.20)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.240->onprem) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.240->onprem) (4.0.3)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain==0.0.240->onprem)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting langsmith<0.1.0,>=0.0.11 (from langchain==0.0.240->onprem)
#   Downloading langsmith-0.0.35-py3-none-any.whl (37 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.240->onprem) (2.8.5)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain==0.0.240->onprem)
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.240->onprem) (8.2.3)
# Requirement already satisfied: diskcache>=5.6.1 in /usr/local/lib/python3.10/dist-packages (from llama-cpp-python==0.1.69->onprem) (5.6.3)
# Collecting plumbum (from pandoc==2.3->onprem)
#   Downloading plumbum-1.8.2-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 15.5 MB/s eta 0:00:00
# Collecting ply (from pandoc==2.3->onprem)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.9 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.23.0 (from PyMuPDF==1.23.1->onprem)
#   Downloading PyMuPDFb-1.23.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (26.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.3/26.3 MB 50.5 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers==2.2.2->onprem)
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 84.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->onprem) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->onprem) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->onprem) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->onprem) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->onprem) (3.8.1)
# Collecting sentencepiece (from sentence-transformers==2.2.2->onprem)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers==2.2.2->onprem)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.8->onprem) (5.2.0)
# Collecting filetype (from unstructured==0.10.8->onprem)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured==0.10.8->onprem)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.8->onprem) (4.9.3)
# Collecting emoji (from unstructured==0.10.8->onprem)
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onprem) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onprem) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onprem) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onprem) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.240->onprem) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.240->onprem) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.240->onprem) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.240->onprem) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.240->onprem) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<4.13,>=4.11.1->extract-msg==0.45.0->onprem) (2.5)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.240->onprem)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.3 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.240->onprem)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->onprem)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2->onprem) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2->onprem) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2->onprem) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imapclient<3,>=2.3.0->extract-msg==0.45.0->onprem) (1.16.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.4.7->onprem)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.7->onprem) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.7->onprem) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.7->onprem) (1.12)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.4.7->onprem)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.4.7->onprem)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.7->onprem) (2.8.2)
# Collecting lark==1.1.5 (from RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem)
#   Downloading lark-1.1.5-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 9.3 MB/s eta 0:00:00
# Collecting oletools>=0.56 (from RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem)
#   Downloading oletools-0.60.1-py2.py3-none-any.whl (977 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 977.2/977.2 kB 63.6 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.240->onprem) (2.0.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2->onprem) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2->onprem) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2->onprem) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers==2.2.2->onprem) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers==2.2.2->onprem) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2->onprem) (2023.6.3)
# Collecting tokenizers>=0.13.2 (from chromadb==0.4.7->onprem)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 84.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2->onprem)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->onprem) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->onprem)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->onprem)
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 26.5 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->onprem)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->onprem)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 82.1 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->onprem)
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.3 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->onprem)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2->onprem) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==2.2.2->onprem) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers==2.2.2->onprem) (9.4.0)
# Collecting pyparsing<3,>=2.1.0 (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.2 MB/s eta 0:00:00
# Collecting easygui (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem)
#   Downloading easygui-0.98.3-py2.py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 11.3 MB/s eta 0:00:00
# Collecting colorclass (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem)
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Collecting pcodedmp>=1.2.5 (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem)
#   Downloading pcodedmp-1.2.6-py2.py3-none-any.whl (30 kB)
# Collecting msoffcrypto-tool (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem)
#   Downloading msoffcrypto_tool-5.1.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->onprem) (3.7.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.240->onprem)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.7->onprem)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers==2.2.2->onprem) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.7->onprem) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->onprem) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->onprem) (1.1.3)
# Requirement already satisfied: cryptography>=35.0 in /usr/local/lib/python3.10/dist-packages (from msoffcrypto-tool->oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem) (41.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=35.0->msoffcrypto-tool->oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=35.0->msoffcrypto-tool->oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->onprem) (2.21)
# Building wheels for collected packages: pandoc, sentence-transformers, chroma-hnswlib, olefile, red-black-tree-mod, compressed-rtf, pypika
#   Building wheel for pandoc (setup.py) ... done
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33261 sha256=8c3d1574ce7c1b8ee27f37cec0040b932863445c3bdb6f00471d121d5653c335
#   Stored in directory: /root/.cache/pip/wheels/76/27/c2/c26175310aadcb8741b77657a1bb49c50cc7d4cdbf9eee0005
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=22e5b677a5898328cadd8194191389e65c7da8ac8d751f67f3db0c09ddfa63f8
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for chroma-hnswlib (pyproject.toml) ... done
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.2-cp310-cp310-linux_x86_64.whl size=2287385 sha256=c63030500ae6c20feacfcf778b3e61c30bcb42c2328dd81839d4527cab04d2b5
#   Stored in directory: /root/.cache/pip/wheels/11/2b/0d/ee457f6782f75315bb5828d5c2dc5639d471afbd44a830b9dc
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=41a1571f714fd0612b6be0fa9ec3de63c7b29904782987d2b3b16cd339ec130c
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
#   Building wheel for red-black-tree-mod (setup.py) ... done
#   Created wheel for red-black-tree-mod: filename=red_black_tree_mod-1.20-py3-none-any.whl size=18622 sha256=112a4f77f0ce4ed6460d2471edeef627327ec2ad71ff2998987ffef87490983a
#   Stored in directory: /root/.cache/pip/wheels/1e/89/a0/17d08e78a59e4e8f51a95fe52e19c6916450c143acc7bce4dd
#   Building wheel for compressed-rtf (setup.py) ... done
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6185 sha256=0b3a0121643d89a44d01fc6fbb2214828b08bfaab92bf31c0dcd40e773dc9f4f
#   Stored in directory: /root/.cache/pip/wheels/15/3e/48/e7d833ecc516c36f8966d310b1a6386db091a718f1ff3bf85c
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=4d1818641fdb40c8399e7e0263a649e95ff145156e3bcb008d4c37888fafd94f
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pandoc sentence-transformers chroma-hnswlib olefile red-black-tree-mod compressed-rtf pypika
# Installing collected packages: tokenizers, sentencepiece, safetensors, red-black-tree-mod, pypika, ply, monotonic, lark, filetype, ebcdic, easygui, compressed-rtf, websockets, uvloop, python-magic, python-dotenv, pyparsing, pypandoc, PyMuPDFb, pulsar-client, plumbum, overrides, olefile, mypy-extensions, marshmallow, imapclient, humanfriendly, httptools, h11, emoji, colorclass, chroma-hnswlib, bcrypt, backoff, watchfiles, uvicorn, unstructured, typing-inspect, starlette, PyMuPDF, posthog, pandoc, openapi-schema-pydantic, langsmith, huggingface-hub, coloredlogs, transformers, onnxruntime, msoffcrypto-tool, fastapi, dataclasses-json, langchain, chromadb, pcodedmp, oletools, RTFDE, sentence-transformers, extract-msg, onprem
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
# Successfully installed PyMuPDF-1.23.1 PyMuPDFb-1.23.0 RTFDE-0.1.0 backoff-2.2.1 bcrypt-4.0.1 chroma-hnswlib-0.7.2 chromadb-0.4.7 colorclass-2.2.2 coloredlogs-15.0.1 compressed-rtf-1.0.6 dataclasses-json-0.5.14 easygui-0.98.3 ebcdic-1.1.1 emoji-2.8.0 extract-msg-0.45.0 fastapi-0.99.1 filetype-1.2.0 h11-0.14.0 httptools-0.6.0 huggingface-hub-0.16.4 humanfriendly-10.0 imapclient-2.3.1 langchain-0.0.240 langsmith-0.0.35 lark-1.1.5 marshmallow-3.20.1 monotonic-1.6 msoffcrypto-tool-5.1.1 mypy-extensions-1.0.0 olefile-0.46 oletools-0.60.1 onnxruntime-1.15.1 onprem-0.0.12 openapi-schema-pydantic-1.2.4 overrides-7.4.0 pandoc-2.3 pcodedmp-1.2.6 plumbum-1.8.2 ply-3.11 posthog-3.0.2 pulsar-client-3.3.0 pypandoc-1.11 pyparsing-2.4.7 pypika-0.48.9 python-dotenv-1.0.0 python-magic-0.4.27 red-black-tree-mod-1.20 safetensors-0.3.3 sentence-transformers-2.2.2 sentencepiece-0.1.99 starlette-0.27.0 tokenizers-0.13.3 transformers-4.33.1 typing-inspect-0.9.0 unstructured-0.10.8 uvicorn-0.23.2 uvloop-0.17.0 watchfiles-0.20.0 websockets-11.0.3

# %% [markdown]
# ## Restart Google Colab Runtime
#
# 如果您在上面安装 `onprem` 后尚未重新启动运行时，请立即重新启动它（运行时-->重新启动运行时）并从下面的单元格开始（即 `from onprem import LLM` ）。**这是必需的，否则您将收到错误。**
#
# **注意：**由于尚不清楚的原因，较新版本的 `llama-python-cpp` 无法在 Google Colab 上加载模型，除非 `verbose=True` 。因此，我们将在下面设置 `verbose=True` （默认值为 `False` ）。

# %%
from onprem import LLM
llm = LLM(n_gpu_layers=32, verbose=True)
# Out:
# You are about to download the LLM Wizard-Vicuna-7B-Uncensored.ggmlv3.q4_0.bin to the /root/onprem_data folder. Are you sure? (y/N) y
# [██████████████████████████████████████████████████]

# %% [markdown]
# 现在，我们可以开始执行提示。请注意，由于模型加载，第一个提示可能会执行缓慢。由于 GPU 卸载，后续提示将会更快。

# %% [markdown]
# ## 信息提取

# %%
prompt = """Extract the Name, Position, and Company from the following sentences.  Here are some examples.
[Text]: Fred is a serial entrepreneur. Co-founder and CEO of Platform.sh, he previously co-founded Commerce Guys, a leading Drupal ecommerce provider. His mission is to guarantee that as we continue on an ambitious journey to profoundly transform how cloud computing is used and perceived, we keep our feet well on the ground continuing the rapid growth we have enjoyed up until now.
[Name]: Fred
[Position]: Co-founder and CEO
[Company]: Platform.sh
###
[Text]: Microsoft (the word being a portmanteau of "microcomputer software") was founded by Bill Gates on April 4, 1975, to develop and sell BASIC interpreters for the Altair 8800. Steve Ballmer replaced Gates as CEO in 2000, and later envisioned a "devices and services" strategy.
[Name]:  Steve Ballmer
[Position]: CEO
[Company]: Microsoft
###
[Text]: Franck Riboud was born on 7 November 1955 in Lyon. He is the son of Antoine Riboud, the previous CEO, who transformed the former European glassmaker BSN Group into a leading player in the food industry. He is the CEO at Danone.
[Name]:  Franck Riboud
[Position]: CEO
[Company]: Danone
###
[Text]: David Melvin is an investment and financial services professional at CITIC CLSA with over 30 years’ experience in investment banking and private equity. He is currently a Senior Adviser of CITIC CLSA.
"""
saved_output = llm.prompt(prompt)
# Out:
# [Name]:  David Melvin
# [Position]: Investment and Financial Services Professional
# [Company]: CITIC CLSA

# %% [markdown]
# ## 语法纠正

# %%
prompt="""Correct the grammar and spelling in the supplied sentences.  Here are some examples.
[Sentence]:
I love goin to the beach.
[Correction]: I love going to the beach.
[Sentence]:
Let me hav it!
[Correction]: Let me have it!
[Sentence]:
It have too many drawbacks.
[Correction]: It has too many drawbacks.
[Sentence]:
I do not wan to go
[Correction]:"""
saved_output = llm.prompt(prompt)
# Out:
#  I don't want to go.

# %% [markdown]
# ## 分类

# %%
prompt="""Classify each sentence as either positive, negative, or neutral.  Here are some examples.
[Sentence]: I love going to the beach.
[[Classification]: Positive
[Sentence]: It is 10am right now.
[Classification]: Neutral
[Sentence]: I just got fired from my job.
[Classification]: Negative
[Sentence]: The reactivity of  your team has been amazing, thanks!
[Classification]:"""

saved_output = llm.prompt(prompt)
# Out:
#  Positive

# %% [markdown]
# ## 释义和总结

# %%
prompt = """Paraphrase the following text delimited by triple backticks.
```After a war lasting 20 years, following the decision taken first by President Trump and then by President Biden to withdraw American troops, Kabul, the capital of Afghanistan, fell within a few hours to the Taliban, without resistance.```
"""
saved_output = llm.prompt(prompt)
# Out:
# Paraphrase: After two decades of war in Afghanistan, with President Trump and later President Biden announcing their plans to withdraw American troops, Kabul, the Afghan capital, quickly fell into the hands of the Taliban without any resistance from local authorities or security forces.

# %% [markdown]
# ## Few-Shot Answer Extraction

# %%
prompt="""Answer the Question based on the Context.  Here are some examples.
[Context]:
NLP Cloud was founded in 2021 when the team realized there was no easy way to reliably leverage Natural Language Processing in production.
Question: When was NLP Cloud founded?
[Answer]:
2021
###
[Context]:
NLP Cloud developed their API by mid-2020 and they added many pre-trained open-source models since then.
[Question]:
What did NLP Cloud develop?
[Answer]:
API
###
[Context]:
All plans can be stopped anytime. You only pay for the time you used the service. In case of a downgrade, you will get a discount on your next invoice.
[Question]:
When can plans be stopped?
[Answer]:
Anytime
###
[Context]:
The main challenge with GPT-J is memory consumption. Using a GPU plan is recommended.
[Question]:
Which plan is recommended for GPT-J?
Answer:"""
saved_output = llm.prompt(prompt)
# Out:
#  GPU Plan

# %% [markdown]
# ## 生成产品描述

# %%
prompt="""Generate a Sentence from the Keywords. Here are some examples.
[Keywords]:
shoes, women, $59
[Sentence]:
Beautiful shoes for women at the price of $59.
###
[Keywords]:
trousers, men, $69
[Sentence]:
Modern trousers for men, for $69 only.
###
[Keywords]:
gloves, winter, $19
[Sentence]:
Amazingly hot gloves for cold winters, at $19.
###
[Keywords]:
t-shirt, men, $39
[Sentence]:"""
saved_output = llm.prompt(prompt)
# Out:
# Classy t-shirts for men, available at $39 only.

# %% [markdown]
# ## 推文生成

# %%
prompt = """Generate a tweet based on the supplied Keyword. Here are some examples.
[Keyword]:
markets
[Tweet]:
Take feedback from nature and markets, not from people
###
[Keyword]:
children
[Tweet]:
Maybe we die so we can come back as children.
###
[Keyword]:
startups
[Tweet]:
Startups should not worry about how to put out fires, they should worry about how to start them.
###
[Keyword]:
climate change
[Tweet]:"""
saved_output = llm.prompt(prompt)
# Out:
# Climate change is a reality we can no longer ignore. Let's take action and protect our planet.

# %% [markdown]
# ## 电子邮件生成

# %%
prompt = """Generate an email introducing Tesla to shareholders."""
saved_output = llm.prompt(prompt)
# Out:
# Subject: Introducing Tesla - A New Era of Electric Vehicles
# Dear Shareholders,
# As a valued Tesla shareholder, I am writing to you today to introduce Tesla and its revolutionary electric vehicles.
# Tesla was founded in 2003 with the mission to accelerate the transition to sustainable energy. We began by developing high-performance electric cars that could be enjoyed not just for their environmental benefits, but also for their performance and design. Today, Tesla is the world's leading electric vehicle manufacturer, with a diverse range of vehicles that cater to different needs and budgets.
# Our Model S sedan is one of the most innovative and advanced vehicles on the market, boasting unmatched acceleration, range, and performance. It has received widespread acclaim from industry experts and customers alike, and was named Motor Trend's 2013 Car of the Year.
# We also offer the Model X SUV and Model 3 sedan, which are both designed to be more affordable yet retain Tesla's signature performance and quality. Our Supercharger network allows our customers to charge their vehicles quickly and easily while on long road trips, making electric driving even more convenient.
# Today, we are launching the Model Y, our first crossover vehicle, which we believe will be a huge success with families and outdoor enthusiasts alike. With its spacious interior, advanced safety features, and impressive range, it is set to become another game-changer in the electric vehicle market.
# At Tesla, our mission is to accelerate the world's transition to sustainable energy. We are committed to creating the most innovative and exciting electric vehicles on the planet, and we believe that together, we can create a better future for ourselves and generations to come.
# Thank you for being a valued Tesla shareholder. We look forward to continuing our journey towards sustainable energy together.

# %% [markdown]
# ## 通过检索增强生成来处理您的文档

# %%
# !mkdir /tmp/sample_data
# !wget --user-agent="Mozilla" https://raw.githubusercontent.com/amaiya/onprem/master/nbs/sample_data/1/ktrain_paper.pdf -O /tmp/sample_data/ktrain_paper.pdf

# %%
llm.ingest('/tmp/sample_data')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Creating new vectorstore at /root/onprem_data/vectordb
# Loading documents from /tmp/sample_data
# Loading new documents: 100%|██████████████████████| 1/1 [00:00<00:00,  3.56it/s]
# Loaded 9 new documents from /tmp/sample_data
# Split into 57 chunks of text (max. 500 tokens each)
# Creating embeddings. May take some minutes...
# Ingestion complete! You can now query your documents using the LLM.ask method

# %%
result = llm.ask('What is ktrain?')
# Out:
#  Ktrain is a low-code library for augmented machine learning that automates or semi-automates various aspects of the ML workow, from preprocessing inputs to applying models. It was inspired by other low-code and no-code open-source ML libraries such as fastai and ludwig, and is intended to further democratize machine learning by enabling beginners and domain experts with minimal programming or data science experience to perform complex ML tasks without the need for extensive coding knowledge.
